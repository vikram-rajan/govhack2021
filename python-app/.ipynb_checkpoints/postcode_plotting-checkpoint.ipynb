# %%
import matplotlib.pyplot as plt
import csv
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('rental_data.csv', sep=',')

# %%
month = data['Month']
year = data['Year']
postcode = data['Postcode']
n = data['# of Bonds']

# %%
month[month == 'January'] = 1
month[month == 'February'] = 2
month[month == 'March'] = 3
month[month == 'April'] = 4
month[month == 'May'] = 5
month[month == 'June'] = 6
month[month == 'July'] = 7
month[month == 'August'] = 8
month[month == 'September'] = 9
month[month == 'October'] = 10
month[month == 'November'] = 11
month[month == 'December'] = 12

month[year == 2019]=month[year == 2019]+12
month[year == 2020]=month[year == 2020]+24
month[year == 2021]=month[year == 2021]+36
# Out:
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\poetr\Anaconda2\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
ind =(postcode == 2009)
plt.plot(month[ind],n[ind],'ko')
plt.ylabel('Number of Bonds')
plt.xlabel('Month Number')
# Out:
# Text(0.5,0,'Month Number')

# %%
data = pd.read_csv('Distance.csv')
postcode = []
for x in data['data']:
    postcode = np.append(postcode, x[0:4])
    
data = pd.read_csv('Distance.csv',delimiter='(')
distance = []
for x in data['data']:
    distance = np.append(distance, x[0:-4])

# %%
distance
# Out:
# array(['0', '0.3', '0.4', ..., '49.8', '49.9', '49.9'], dtype='|S32')

# %%
data = pd.read_csv('Distance.csv',delimiter='(')

# %%
data['data'][1000][0:-4]
# Out:
# '38.9'

# %%
data
# Out:
#                                     data
# 2000 Barangaroo                    0 km)
# 2000 Millers Point               0.3 km)
# 2795 Charles Sturt University    0.4 km)
# 1220 Grosvenor Place             0.4 km)
# 2000 The Rocks                   0.5 km)
# 1215 Australia Square            0.6 km)
# 1229 Queen Victoria Building     0.6 km)
# 1227 Queen Victoria Building     0.6 km)
# 1228 Queen Victoria Building     0.6 km)
# 1226 Queen Victoria Building     0.7 km)
# 2000 Sydney                      0.7 km)
# 1225 Royal Exchange              0.7 km)
# 2000 Dawes Point                 0.7 km)
# 2000 Parliament House              1 km)
# 2041 Balmain East                  1 km)
# 1235 Sydney South                1.1 km)
# 2009 Pyrmont                     1.1 km)
# 1230 Queen Victoria Building     1.2 km)
# 1335 Potts Point                 1.3 km)
# 1239 Haymarket                   1.3 km)
# 1298 Sydney                      1.4 km)
# 1293 Sydney                      1.4 km)
# 1236 Haymarket                   1.4 km)
# 1291 Sydney                      1.4 km)
# 1295 Sydney                      1.4 km)
# 1292 Sydney                      1.4 km)
# 1231 Sydney South                1.4 km)
# 1299 Sydney                      1.4 km)
# 1294 Sydney                      1.4 km)
# 1237 Haymarket                   1.4 km)
# ...                                  ...
# 2251 Avoca Beach                47.2 km)
# 2777 Yellow Rock                47.4 km)
# 2251 Picketts Valley            47.5 km)
# 2515 Clifton                    47.5 km)
# 2753 Yarramundi                 47.7 km)
# 2754 North Richmond             47.7 km)
# 2774 Warrimoo                   47.8 km)
# 2250 Point Clare                47.8 km)
# 2260 North Avoca                47.9 km)
# 2250 East Gosford               48.2 km)
# 2775 Gunderman                  48.3 km)
# 2753 Grose Wold                 48.3 km)
# 2570 Mount Hunter               48.4 km)
# 2570 Cawdor                     48.6 km)
# 2515 Scarborough                48.6 km)
# 2777 Winmalee                   48.7 km)
# 2250 Erina                      48.8 km)
# 2250 West Gosford               48.8 km)
# 2756 Glossodia                  48.8 km)
# 2777 Sun Valley                 48.9 km)
# 2560 Appin                        49 km)
# 2250 Erina Fair                 49.1 km)
# 2250 Gosford                    49.2 km)
# 2260 Terrigal                   49.3 km)
# 2250 Springfield                49.4 km)
# 2777 Valley Heights             49.7 km)
# 2570 Werombi                    49.7 km)
# 2515 Wombarra                   49.8 km)
# 2250 Lower Mangrove             49.9 km)
# 2508 Maddens Plains             49.9 km)
#
# [1149 rows x 1 columns]
